# %% [markdown]
# <a href="https://colab.research.google.com/github/woraphonp-038-5/Project_Dashboard_BasicPrograming/blob/main/witsy_of_Manage_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1

# %%
import os
import pandas as pd

folder_path = '/content/drive/MyDrive/Pythondataviz/data/2025-01' # Update with the actual path if different

street_files = []
for root, dirs, files in os.walk(folder_path):
  for file in files:
    if '-street' in file and file.endswith(".csv"): # Filter for '-street' in filename and assume CSVs
      file_path = os.path.join(root, file)
      df = pd.read_csv(file_path)
      street_files.append(df)

# Concatenate all DataFrames into a single DataFrame if needed
combined_street_df1 = pd.concat(street_files, ignore_index=True)

# Display the first few rows of the combined DataFrame
if street_files: # Check if the list of files is not empty
    combined_street_df = pd.concat(street_files, ignore_index=True)
    display(combined_street_df.head())
else:
    print("No files containing '-street' were found in the specified folder.")

print(f"Read {len(street_files)} files containing '-street' from {folder_path}")
# Out:
#                                             Crime ID    Month  \
# 0  6c842468106b228e4d97943630dcf12113f048f9c00709...  2025-01
# 1  59527277bc9fb539d30f1ab24a0fb3f90a6d5172005559...  2025-01
# 2  670a09c85cb53d575f72378be4a926f67f682782da98de...  2025-01
# 3  65fcc2d4fd81432b9471596d8755c761ee5a3ee489fad4...  2025-01
# 4  350fc94f0c6fa1496f3296188b93c211d2114ad7275806...  2025-01
#
#             Reported by          Falls within  Longitude   Latitude  \
# 0  Norfolk Constabulary  Norfolk Constabulary   0.145908  51.541559
# 1  Norfolk Constabulary  Norfolk Constabulary   0.145908  51.541559
# 2  Norfolk Constabulary  Norfolk Constabulary   0.145908  51.541559
# 3  Norfolk Constabulary  Norfolk Constabulary   0.138162  51.467959
# 4  Norfolk Constabulary  Norfolk Constabulary   0.127364  51.460233
#
#                        Location  LSOA code                  LSOA name  \
# 0  On or near Dagenham Heathway  E01000013  Barking and Dagenham 013A
# ...

# %%
combined_street_df1
# Out:
#                                                  Crime ID    Month  \
# 0       6c842468106b228e4d97943630dcf12113f048f9c00709...  2025-01
# 1       59527277bc9fb539d30f1ab24a0fb3f90a6d5172005559...  2025-01
# 2       670a09c85cb53d575f72378be4a926f67f682782da98de...  2025-01
# 3       65fcc2d4fd81432b9471596d8755c761ee5a3ee489fad4...  2025-01
# 4       350fc94f0c6fa1496f3296188b93c211d2114ad7275806...  2025-01
# ...                                                   ...      ...
# 443695  7cbbcf7fbd15897888e5d511affbec5a59ef37f17c4f95...  2025-01
# 443696  fab1b577a8997202de3631c11deabed9a9a77f4abda9df...  2025-01
# 443697  b23dec85b13c028350101f1b1bc81c52c12d945147b1e0...  2025-01
# 443698  b06803e3ed8735fe051e78a0fceb84a5b96ce560585bf7...  2025-01
# 443699  b3ef443f79b4514feb78f999bc96b02b2d4f94164e5107...  2025-01
#
#                  Reported by          Falls within  Longitude   Latitude  \
# 0       Norfolk Constabulary  Norfolk Constabulary   0.145908  51.541559
# ...

# %%
folder_path = '/content/drive/MyDrive/Pythondataviz/data/2025-02' # Update with the actual path if different

street_files = []
for root, dirs, files in os.walk(folder_path):
  for file in files:
    if '-street' in file and file.endswith(".csv"): # Filter for '-street' in filename and assume CSVs
      file_path = os.path.join(root, file)
      df = pd.read_csv(file_path)
      street_files.append(df)

# Concatenate all DataFrames into a single DataFrame if needed
combined_street_df2 = pd.concat(street_files, ignore_index=True)

# Display the first few rows of the combined DataFrame
if street_files: # Check if the list of files is not empty
    combined_street_df = pd.concat(street_files, ignore_index=True)
    display(combined_street_df.head())
else:
    print("No files containing '-street' were found in the specified folder.")

print(f"Read {len(street_files)} files containing '-street' from {folder_path}")
# Out:
#                                             Crime ID    Month  \
# 0                                                NaN  2025-02
# 1  21cc2acd49b17a3ca6a515098958f5be70255e29b81c99...  2025-02
# 2                                                NaN  2025-02
# 3                                                NaN  2025-02
# 4                                                NaN  2025-02
#
#            Reported by         Falls within  Longitude   Latitude  \
# 0  Lincolnshire Police  Lincolnshire Police   0.068963  52.981902
# 1  Lincolnshire Police  Lincolnshire Police   0.068963  52.981902
# 2  Lincolnshire Police  Lincolnshire Police   0.050111  52.975764
# 3  Lincolnshire Police  Lincolnshire Police   0.060653  52.948456
# 4  Lincolnshire Police  Lincolnshire Police   0.054740  52.987300
#
#                      Location  LSOA code    LSOA name  \
# 0      On or near Upsall Road  E01026007  Boston 001A
# 1      On or near Upsall Road  E01026007  Boston 001A
# ...

# %%
combined_street_df2
# Out:
#                                                  Crime ID    Month  \
# 0                                                     NaN  2025-02
# 1       21cc2acd49b17a3ca6a515098958f5be70255e29b81c99...  2025-02
# 2                                                     NaN  2025-02
# 3                                                     NaN  2025-02
# 4                                                     NaN  2025-02
# ...                                                   ...      ...
# 188982  be29fb1eea2c2ab41969b1262407b575e91763e5958db2...  2025-02
# 188983  0c7718d9cbc6ffc7a1f37f06d56fc6f00e5e4b203f75d6...  2025-02
# 188984  ad6637f6133d4d151d1d7e85f0b8c46e5b00159118fdfe...  2025-02
# 188985  0ca8f2ef6a36c44c4dee943ce84bc6b3bf2134bab67cf0...  2025-02
# 188986  6fce89bccb67bf3a07cfe097e94266c5f7093fc851c3e7...  2025-02
#
#                 Reported by         Falls within  Longitude   Latitude  \
# 0       Lincolnshire Police  Lincolnshire Police   0.068963  52.981902
# ...

# %%
folder_path = '/content/drive/MyDrive/Pythondataviz/data/2025-03' # Update with the actual path if different

street_files = []
for root, dirs, files in os.walk(folder_path):
  for file in files:
    if '-street' in file and file.endswith(".csv"): # Filter for '-street' in filename and assume CSVs
      file_path = os.path.join(root, file)
      df = pd.read_csv(file_path)
      street_files.append(df)

# Concatenate all DataFrames into a single DataFrame if needed
combined_street_df3 = pd.concat(street_files, ignore_index=True)

# Display the first few rows of the combined DataFrame
if street_files: # Check if the list of files is not empty
    combined_street_df = pd.concat(street_files, ignore_index=True)
    display(combined_street_df.head())
else:
    print("No files containing '-street' were found in the specified folder.")

print(f"Read {len(street_files)} files containing '-street' from {folder_path}")
# Out:
#                                             Crime ID    Month  \
# 0  9f3842c40b68482239b4ee032201fb977b619381326e84...  2025-03
# 1  f40728583304581693ab0aef9732a89f0f1d37d82c3974...  2025-03
# 2  ec97d70a95e6eb4f65542b814b709f88e509ff7060b28c...  2025-03
# 3  61a28151fba04d8cd4c34bfb277ceebbf774f088c8c6df...  2025-03
# 4  33b3471591c9510a5f070023cac34fe7b13fb6ae78d7f1...  2025-03
#
#         Reported by      Falls within  Longitude   Latitude  \
# 0  Wiltshire Police  Wiltshire Police  -3.205084  54.120092
# 1  Wiltshire Police  Wiltshire Police  -2.391218  51.391665
# 2  Wiltshire Police  Wiltshire Police  -1.757463  51.882848
# 3  Wiltshire Police  Wiltshire Police  -2.267875  51.293121
# 4  Wiltshire Police  Wiltshire Police  -2.379004  51.287635
#
#                       Location  LSOA code                          LSOA name  \
# 0       On or near Middle Hill  E01019160             Barrow-in-Furness 007B
# ...

# %%
combined_street_df3
# Out:
#                                                 Crime ID    Month  \
# 0      9f3842c40b68482239b4ee032201fb977b619381326e84...  2025-03
# 1      f40728583304581693ab0aef9732a89f0f1d37d82c3974...  2025-03
# 2      ec97d70a95e6eb4f65542b814b709f88e509ff7060b28c...  2025-03
# 3      61a28151fba04d8cd4c34bfb277ceebbf774f088c8c6df...  2025-03
# 4      33b3471591c9510a5f070023cac34fe7b13fb6ae78d7f1...  2025-03
# ...                                                  ...      ...
# 16996  da86b67502b30d96e06ec2e48e344efed1081aaf30ec76...  2025-03
# 16997  0e3a32fa19c033408525df273008aa45fa10ad7d2126e3...  2025-03
# 16998  cb1f31d29924c8ef7ac283b4d22756a220d49cc4d70b33...  2025-03
# 16999  5f0ebbc07646a071d2d1a34ef3c9aa4cbed9c59fc29d01...  2025-03
# 17000  d2dee8f651c1de2999fdd8959e217216be97206a2d4f6a...  2025-03
#
#                 Reported by          Falls within  Longitude   Latitude  \
# 0          Wiltshire Police      Wiltshire Police  -3.205084  54.120092
# ...

# %%
folder_path = '/content/drive/MyDrive/Pythondataviz/data/2025-04' # Update with the actual path if different

street_files = []
for root, dirs, files in os.walk(folder_path):
  for file in files:
    if '-street' in file and file.endswith(".csv"): # Filter for '-street' in filename and assume CSVs
      file_path = os.path.join(root, file)
      df = pd.read_csv(file_path)
      street_files.append(df)

# Concatenate all DataFrames into a single DataFrame if needed
combined_street_df4 = pd.concat(street_files, ignore_index=True)

# Display the first few rows of the combined DataFrame
if street_files: # Check if the list of files is not empty
    combined_street_df = pd.concat(street_files, ignore_index=True)
    display(combined_street_df.head())
else:
    print("No files containing '-street' were found in the specified folder.")

print(f"Read {len(street_files)} files containing '-street' from {folder_path}")
# Out:
#                                             Crime ID    Month  \
# 0  b7dc0ac996bc0c0570819482bc06dc7a17d4150ab1de42...  2025-04
# 1  c9877d69c1f144e288540abee5f9387fe293a709988b4c...  2025-04
# 2  d8402bf5cb5b34799377efaf705f84eed16b66bb34b599...  2025-04
# 3  d77a5d5b2510b92e9ecc9a8b84f99ed1918a51581e5c4b...  2025-04
# 4  b23c1207c98960afd9e0d7f2d6d1e71aa907a4245a436d...  2025-04
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  City of London Police  City of London Police  -0.107682  51.517786
# 1  City of London Police  City of London Police  -0.107682  51.517786
# 2  City of London Police  City of London Police  -0.107682  51.517786
# 3  City of London Police  City of London Police  -0.107682  51.517786
# 4  City of London Police  City of London Police  -0.111596  51.518281
#
#                    Location  LSOA code    LSOA name             Crime type  \
# 0           On or near B521  E01000917  Camden 027C            Other theft
# ...

# %%
combined_street_df4
# Out:
#                                                 Crime ID    Month  \
# 0      b7dc0ac996bc0c0570819482bc06dc7a17d4150ab1de42...  2025-04
# 1      c9877d69c1f144e288540abee5f9387fe293a709988b4c...  2025-04
# 2      d8402bf5cb5b34799377efaf705f84eed16b66bb34b599...  2025-04
# 3      d77a5d5b2510b92e9ecc9a8b84f99ed1918a51581e5c4b...  2025-04
# 4      b23c1207c98960afd9e0d7f2d6d1e71aa907a4245a436d...  2025-04
# ...                                                  ...      ...
# 17038  7c6166517bfae76c6c711c8b06fbd27509ec6a22d2ae84...  2025-04
# 17039  ed101c0e0f020a24133971dcac24f8b84628416c8d7ee8...  2025-04
# 17040  083694e17f6c7cca302bc7714cd52644e12d257e6b9e21...  2025-04
# 17041  ecbe79ca5c25cc42d76ab4762b08b799501ff6d2d2e82f...  2025-04
# 17042  4212ff3ceadfe1c48f8a75ffaa445a5d435a662d8eba81...  2025-04
#
#                  Reported by           Falls within  Longitude   Latitude  \
# 0      City of London Police  City of London Police  -0.107682  51.517786
# ...

# %%
folder_path = '/content/drive/MyDrive/Pythondataviz/data/2025-05' # Update with the actual path if different

street_files = []
for root, dirs, files in os.walk(folder_path):
  for file in files:
    if '-street' in file and file.endswith(".csv"): # Filter for '-street' in filename and assume CSVs
      file_path = os.path.join(root, file)
      df = pd.read_csv(file_path)
      street_files.append(df)

# Concatenate all DataFrames into a single DataFrame if needed
combined_street_df5 = pd.concat(street_files, ignore_index=True)

# Display the first few rows of the combined DataFrame
if street_files: # Check if the list of files is not empty
    combined_street_df = pd.concat(street_files, ignore_index=True)
    display(combined_street_df.head())
else:
    print("No files containing '-street' were found in the specified folder.")

print(f"Read {len(street_files)} files containing '-street' from {folder_path}")
# Out:
#                                             Crime ID    Month  \
# 0  bb467638f78d31189ffd2294515e8a8cc1a976fd720453...  2025-05
# 1  b6b38be1eaa8510683284967e095db94cfd203facea698...  2025-05
# 2  df7330c02016f9782c9a6070034a423d5fd389a4f7cab3...  2025-05
# 3  7918cab5fbcae616f0ccf2a56bdef5d28d941820cdaee9...  2025-05
# 4  696925d19f5fa003c204a13dd9c87e1b464c4b6b56f95e...  2025-05
#
#           Reported by        Falls within  Longitude   Latitude  \
# 0  Dyfed-Powys Police  Dyfed-Powys Police  -3.500035  51.524261
# 1  Dyfed-Powys Police  Dyfed-Powys Police  -0.593177  51.679337
# 2  Dyfed-Powys Police  Dyfed-Powys Police  -3.275522  51.751739
# 3  Dyfed-Powys Police  Dyfed-Powys Police  -3.265298  51.596761
# 4  Dyfed-Powys Police  Dyfed-Powys Police  -2.032267  52.687631
#
#                   Location  LSOA code             LSOA name  \
# 0   On or near Supermarket  W01001004         Bridgend 009A
# 1      On or near New Road  E01017741  Buckinghamshire 032A
# ...

# %%
combined_street_df5
# Out:
#                                                 Crime ID    Month  \
# 0      bb467638f78d31189ffd2294515e8a8cc1a976fd720453...  2025-05
# 1      b6b38be1eaa8510683284967e095db94cfd203facea698...  2025-05
# 2      df7330c02016f9782c9a6070034a423d5fd389a4f7cab3...  2025-05
# 3      7918cab5fbcae616f0ccf2a56bdef5d28d941820cdaee9...  2025-05
# 4      696925d19f5fa003c204a13dd9c87e1b464c4b6b56f95e...  2025-05
# ...                                                  ...      ...
# 17940  c73a19e8066d8b25412ad81d00f9b54fae91ef30093f91...  2025-05
# 17941  e6912d9619a46e5bd3c497df787c1fd33e8ef2e62d4a49...  2025-05
# 17942  21f16dedc869d33913f9d004a3e95913e5d8fa2e6b5a5f...  2025-05
# 17943  0ac70d59536954f60110fb47d338d40d486314af217a8b...  2025-05
# 17944  84ea5f38b46e9f567d9b4e2259e366f370cb8a913852be...  2025-05
#
#               Reported by        Falls within  Longitude   Latitude  \
# 0      Dyfed-Powys Police  Dyfed-Powys Police  -3.500035  51.524261
# ...

# %%
all_street_df = pd.concat([combined_street_df1, combined_street_df2, combined_street_df3, combined_street_df4, combined_street_df5], ignore_index=True)

# %%
all_street_df
# Out:
#                                                  Crime ID    Month  \
# 0       6c842468106b228e4d97943630dcf12113f048f9c00709...  2025-01
# 1       59527277bc9fb539d30f1ab24a0fb3f90a6d5172005559...  2025-01
# 2       670a09c85cb53d575f72378be4a926f67f682782da98de...  2025-01
# 3       65fcc2d4fd81432b9471596d8755c761ee5a3ee489fad4...  2025-01
# 4       350fc94f0c6fa1496f3296188b93c211d2114ad7275806...  2025-01
# ...                                                   ...      ...
# 684671  c73a19e8066d8b25412ad81d00f9b54fae91ef30093f91...  2025-05
# 684672  e6912d9619a46e5bd3c497df787c1fd33e8ef2e62d4a49...  2025-05
# 684673  21f16dedc869d33913f9d004a3e95913e5d8fa2e6b5a5f...  2025-05
# 684674  0ac70d59536954f60110fb47d338d40d486314af217a8b...  2025-05
# 684675  84ea5f38b46e9f567d9b4e2259e366f370cb8a913852be...  2025-05
#
#                  Reported by          Falls within  Longitude   Latitude  \
# 0       Norfolk Constabulary  Norfolk Constabulary   0.145908  51.541559
# ...

# %% [markdown]
# # Clean data

# %%
all_street_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 684676 entries, 0 to 684675
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Crime ID               584485 non-null  object
#  1   Month                  684676 non-null  object
#  2   Reported by            684676 non-null  object
#  3   Falls within           684676 non-null  object
#  4   Longitude              673045 non-null  float64
#  5   Latitude               673045 non-null  float64
#  6   Location               684676 non-null  object
#  7   LSOA code              672940 non-null  object
#  8   LSOA name              672940 non-null  object
#  9   Crime type             684676 non-null  object
#  10  Last outcome category  584485 non-null  object
#  11  Context                0 non-null       float64
# dtypes: float64(3), object(9)
# memory usage: 62.7+ MB

# %%
all_street_df.isnull().any()
# Out:
# Crime ID                  True
# Month                    False
# Reported by              False
# Falls within             False
# Longitude                 True
# Latitude                  True
# Location                 False
# LSOA code                 True
# LSOA name                 True
# Crime type               False
# Last outcome category     True
# Context                   True
# dtype: bool

# %%
all_street_df.isnull().sum()
# Out:
# Crime ID                 100191
# Month                         0
# Reported by                   0
# Falls within                  0
# Longitude                 11631
# Latitude                  11631
# Location                      0
# LSOA code                 11736
# LSOA name                 11736
# Crime type                    0
# Last outcome category    100191
# Context                  684676
# dtype: int64

# %%
# Drop rows with missing values in specified columns
cleaned_street_df = all_street_df.dropna(subset=['Crime ID', 'Longitude', 'Latitude', 'LSOA code', 'LSOA name'])

# Fill missing values in specified columns with 'UNKNOWN'
cleaned_street_df['Last outcome category'] = cleaned_street_df['Last outcome category'].fillna('UNKNOWN')
cleaned_street_df['Context'] = cleaned_street_df['Context'].fillna('UNKNOWN')

display(cleaned_street_df.isnull().sum())
# Out:
# /tmp/ipython-input-618485262.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_street_df['Last outcome category'] = cleaned_street_df['Last outcome category'].fillna('UNKNOWN')
# /tmp/ipython-input-618485262.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_street_df['Context'] = cleaned_street_df['Context'].fillna('UNKNOWN')
# Crime ID                 0
# Month                    0
# Reported by              0
# Falls within             0
# Longitude                0
# ...

# %%
cleaned_street_df
# Out:
#                                                  Crime ID    Month  \
# 0       6c842468106b228e4d97943630dcf12113f048f9c00709...  2025-01
# 1       59527277bc9fb539d30f1ab24a0fb3f90a6d5172005559...  2025-01
# 2       670a09c85cb53d575f72378be4a926f67f682782da98de...  2025-01
# 3       65fcc2d4fd81432b9471596d8755c761ee5a3ee489fad4...  2025-01
# 4       350fc94f0c6fa1496f3296188b93c211d2114ad7275806...  2025-01
# ...                                                   ...      ...
# 684671  c73a19e8066d8b25412ad81d00f9b54fae91ef30093f91...  2025-05
# 684672  e6912d9619a46e5bd3c497df787c1fd33e8ef2e62d4a49...  2025-05
# 684673  21f16dedc869d33913f9d004a3e95913e5d8fa2e6b5a5f...  2025-05
# 684674  0ac70d59536954f60110fb47d338d40d486314af217a8b...  2025-05
# 684675  84ea5f38b46e9f567d9b4e2259e366f370cb8a913852be...  2025-05
#
#                  Reported by          Falls within  Longitude   Latitude  \
# 0       Norfolk Constabulary  Norfolk Constabulary   0.145908  51.541559
# ...
