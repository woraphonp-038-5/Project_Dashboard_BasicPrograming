# %% [markdown]
# <a href="https://colab.research.google.com/github/woraphonp-038-5/Project_Dashboard_BasicPrograming/blob/main/witsy_of_Manage_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1

# %%
import os
import pandas as pd

folder_path = '/content/drive/MyDrive/Python&DataViz2025/2025-01' # Update with the actual path if different

street_files = []
for root, dirs, files in os.walk(folder_path):
  for file in files:
    if '-street' in file and file.endswith(".csv"): # Filter for '-street' in filename and assume CSVs
      file_path = os.path.join(root, file)
      df = pd.read_csv(file_path)
      street_files.append(df)

# Concatenate all DataFrames into a single DataFrame if needed
combined_street_df1 = pd.concat(street_files, ignore_index=True)

# Display the first few rows of the combined DataFrame
if street_files: # Check if the list of files is not empty
    combined_street_df = pd.concat(street_files, ignore_index=True)
    display(combined_street_df.head())
else:
    print("No files containing '-street' were found in the specified folder.")

print(f"Read {len(street_files)} files containing '-street' from {folder_path}")
# Out:
#                                             Crime ID    Month  \
# 0  8c7661d1b68d476454c5b68a58daee0d91781a94f60015...  2025-01
# 1  1b7fbc8deac5182e6b1e580ab4eb4ed520df688c3576bc...  2025-01
# 2  8476f32b188fae2d0d14b7db79e872fd7688f064e8ced3...  2025-01
# 3  92b8de6e45c3b711e802fb9d99e2a030c3f56b1c589e55...  2025-01
# 4  023587ed2c674a28bd52d6e03d505c3b0dba6d25e8b95b...  2025-01
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  City of London Police  City of London Police  -0.107682  51.517786
# 1  City of London Police  City of London Police  -0.111596  51.518281
# 2  City of London Police  City of London Police  -0.097078  51.519045
# 3  City of London Police  City of London Police  -0.097290  51.521575
# 4  City of London Police  City of London Police  -0.098519  51.517332
#
#                     Location  LSOA code            LSOA name  \
# 0            On or near B521  E01000917          Camden 027C
# 1   On or near Chancery Lane  E01000914          Camden 028B
# 2              On or near A1  E01000001  City of London 001A
# 3     On or near Fann Street  E01000001  City of London 001A
# 4  On or near Little Britain  E01000001  City of London 001A
#
#               Crime type                              Last outcome category  \
# 0            Other theft      Investigation complete; no suspect identified
# 1  Theft from the person      Investigation complete; no suspect identified
# 2                  Drugs  Further investigation is not in the public int...
# 3            Other theft      Investigation complete; no suspect identified
# 4            Other theft      Investigation complete; no suspect identified
#
#    Context
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# Read 43 files containing '-street' from /content/drive/MyDrive/Python&DataViz2025/2025-01

# %%
combined_street_df1
# Out:
#                                                  Crime ID    Month  \
# 0       8c7661d1b68d476454c5b68a58daee0d91781a94f60015...  2025-01
# 1       1b7fbc8deac5182e6b1e580ab4eb4ed520df688c3576bc...  2025-01
# 2       8476f32b188fae2d0d14b7db79e872fd7688f064e8ced3...  2025-01
# 3       92b8de6e45c3b711e802fb9d99e2a030c3f56b1c589e55...  2025-01
# 4       023587ed2c674a28bd52d6e03d505c3b0dba6d25e8b95b...  2025-01
# ...                                                   ...      ...
# 443695  94e6c52fd11d64c2b862369b53a2d3a17fa85be50f767f...  2025-01
# 443696  5504f52c9890a6322c905bd7934177aad6e75437cb274e...  2025-01
# 443697  b8853d9a9662ee4dcba7995a8f316f5f538c6883f469c4...  2025-01
# 443698  2f5db85218dafefee0ef81fedff9f8618b7268f52a12d7...  2025-01
# 443699  0d96562bc6293e1206de0c3ac0edb049b8164ad678cff7...  2025-01
#
#                         Reported by                 Falls within  Longitude  \
# 0             City of London Police        City of London Police  -0.107682
# 1             City of London Police        City of London Police  -0.111596
# 2             City of London Police        City of London Police  -0.097078
# 3             City of London Police        City of London Police  -0.097290
# 4             City of London Police        City of London Police  -0.098519
# ...                             ...                          ...        ...
# 443695  Metropolitan Police Service  Metropolitan Police Service  -0.774921
# 443696  Metropolitan Police Service  Metropolitan Police Service  -0.606469
# 443697  Metropolitan Police Service  Metropolitan Police Service  -3.085995
# 443698  Metropolitan Police Service  Metropolitan Police Service  -0.536160
# 443699  Metropolitan Police Service  Metropolitan Police Service  -0.414598
#
#          Latitude                      Location  LSOA code  \
# 0       51.517786               On or near B521  E01000917
# 1       51.518281      On or near Chancery Lane  E01000914
# 2       51.519045                 On or near A1  E01000001
# 3       51.521575        On or near Fann Street  E01000001
# 4       51.517332     On or near Little Britain  E01000001
# ...           ...                           ...        ...
# 443695  51.563240  On or near Stoney Ware Close  E01016531
# 443696  51.482123        On or near Church Lane  E01016544
# 443697  53.327716        On or near Border Road  E01007189
# 443698  51.329945     On or near Bentham Avenue  E01034293
# 443699  50.836634      On or near Ivydore Close  E01031792
#
#                           LSOA name                    Crime type  \
# 0                       Camden 027C                   Other theft
# 1                       Camden 028B         Theft from the person
# 2               City of London 001A                         Drugs
# 3               City of London 001A                   Other theft
# 4               City of London 001A                   Other theft
# ...                             ...                           ...
# 443695  Windsor and Maidenhead 002B  Violence and sexual offences
# 443696  Windsor and Maidenhead 010A         Possession of weapons
# 443697                  Wirral 040D  Violence and sexual offences
# 443698                  Woking 004G  Violence and sexual offences
# 443699                Worthing 003A  Violence and sexual offences
#
#                                     Last outcome category  Context
# 0           Investigation complete; no suspect identified      NaN
# 1           Investigation complete; no suspect identified      NaN
# 2       Further investigation is not in the public int...      NaN
# 3           Investigation complete; no suspect identified      NaN
# 4           Investigation complete; no suspect identified      NaN
# ...                                                   ...      ...
# 443695                                Under investigation      NaN
# 443696                                Under investigation      NaN
# 443697         Action to be taken by another organisation      NaN
# 443698                        Unable to prosecute suspect      NaN
# 443699      Investigation complete; no suspect identified      NaN
#
# [443700 rows x 12 columns]

# %%
folder_path = '/content/drive/MyDrive/Python&DataViz2025/2025-02' # Update with the actual path if different

street_files = []
for root, dirs, files in os.walk(folder_path):
  for file in files:
    if '-street' in file and file.endswith(".csv"): # Filter for '-street' in filename and assume CSVs
      file_path = os.path.join(root, file)
      df = pd.read_csv(file_path)
      street_files.append(df)

# Concatenate all DataFrames into a single DataFrame if needed
combined_street_df2 = pd.concat(street_files, ignore_index=True)

# Display the first few rows of the combined DataFrame
if street_files: # Check if the list of files is not empty
    combined_street_df = pd.concat(street_files, ignore_index=True)
    display(combined_street_df.head())
else:
    print("No files containing '-street' were found in the specified folder.")

print(f"Read {len(street_files)} files containing '-street' from {folder_path}")
# Out:
#                                             Crime ID    Month  \
# 0  279f546357bfe6387ee11ddb7ae7dfa7bb5b8869a26bee...  2025-02
# 1  39275cdce8d27f8435e32cd7ea924b71e9356370df1cc9...  2025-02
# 2  9e9e753841640599e19698463ccbb38bb0f20983d9b2b6...  2025-02
# 3  44a730ec3aee48500495be2ccc2d219a567eaab964bb4b...  2025-02
# 4  5e4cc320bf0c96cded38440a3c77b0c519828239d924ef...  2025-02
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  City of London Police  City of London Police  -0.106220  51.518275
# 1  City of London Police  City of London Police  -0.113212  51.516841
# 2  City of London Police  City of London Police  -0.111596  51.518281
# 3  City of London Police  City of London Police  -0.111596  51.518281
# 4  City of London Police  City of London Police  -0.128196  51.514537
#
#                       Location  LSOA code    LSOA name             Crime type  \
# 0              On or near B500  E01000916  Camden 027B  Theft from the person
# 1        On or near Old Square  E01000914  Camden 028B               Burglary
# 2     On or near Chancery Lane  E01000914  Camden 028B            Other theft
# 3     On or near Chancery Lane  E01000914  Camden 028B  Theft from the person
# 4  On or near St Giles Passage  E01000919  Camden 028D  Theft from the person
#
#                            Last outcome category  Context
# 0  Investigation complete; no suspect identified      NaN
# 1                            Under investigation      NaN
# 2  Investigation complete; no suspect identified      NaN
# 3  Investigation complete; no suspect identified      NaN
# 4                            Under investigation      NaN
# Read 28 files containing '-street' from /content/drive/MyDrive/Python&DataViz2025/2025-02

# %%
combined_street_df2
# Out:
#                                                  Crime ID    Month  \
# 0       279f546357bfe6387ee11ddb7ae7dfa7bb5b8869a26bee...  2025-02
# 1       39275cdce8d27f8435e32cd7ea924b71e9356370df1cc9...  2025-02
# 2       9e9e753841640599e19698463ccbb38bb0f20983d9b2b6...  2025-02
# 3       44a730ec3aee48500495be2ccc2d219a567eaab964bb4b...  2025-02
# 4       5e4cc320bf0c96cded38440a3c77b0c519828239d924ef...  2025-02
# ...                                                   ...      ...
# 188982  fcb2481b91586b432c51c2184128d40ecf2c87fb4c9ad4...  2025-02
# 188983  6d767460fe999d0353ecaf072e3017753a7db624ee42e9...  2025-02
# 188984  001790086fc16f905364c30868f5d5236dfc12085ec349...  2025-02
# 188985  41f022ea71bdf14db74ca9370c32cabb545264b6d311c7...  2025-02
# 188986  fcb2481b91586b432c51c2184128d40ecf2c87fb4c9ad4...  2025-02
#
#                   Reported by           Falls within  Longitude   Latitude  \
# 0       City of London Police  City of London Police  -0.106220  51.518275
# 1       City of London Police  City of London Police  -0.113212  51.516841
# 2       City of London Police  City of London Police  -0.111596  51.518281
# 3       City of London Police  City of London Police  -0.111596  51.518281
# 4       City of London Police  City of London Police  -0.128196  51.514537
# ...                       ...                    ...        ...        ...
# 188982   Thames Valley Police   Thames Valley Police        NaN        NaN
# 188983   Thames Valley Police   Thames Valley Police        NaN        NaN
# 188984   Thames Valley Police   Thames Valley Police        NaN        NaN
# 188985   Thames Valley Police   Thames Valley Police        NaN        NaN
# 188986   Thames Valley Police   Thames Valley Police        NaN        NaN
#
#                            Location  LSOA code    LSOA name  \
# 0                   On or near B500  E01000916  Camden 027B
# 1             On or near Old Square  E01000914  Camden 028B
# 2          On or near Chancery Lane  E01000914  Camden 028B
# 3          On or near Chancery Lane  E01000914  Camden 028B
# 4       On or near St Giles Passage  E01000919  Camden 028D
# ...                             ...        ...          ...
# 188982                  No Location        NaN          NaN
# 188983                  No Location        NaN          NaN
# 188984                  No Location        NaN          NaN
# 188985                  No Location        NaN          NaN
# 188986                  No Location        NaN          NaN
#
#                    Crime type  \
# 0       Theft from the person
# 1                    Burglary
# 2                 Other theft
# 3       Theft from the person
# 4       Theft from the person
# ...                       ...
# 188982            Other crime
# 188983            Other crime
# 188984            Other crime
# 188985            Other crime
# 188986            Other crime
#
#                                     Last outcome category  Context
# 0           Investigation complete; no suspect identified      NaN
# 1                                     Under investigation      NaN
# 2           Investigation complete; no suspect identified      NaN
# 3           Investigation complete; no suspect identified      NaN
# 4                                     Under investigation      NaN
# ...                                                   ...      ...
# 188982                                Under investigation      NaN
# 188983  Further investigation is not in the public int...      NaN
# 188984                                Under investigation      NaN
# 188985                        Unable to prosecute suspect      NaN
# 188986  Further investigation is not in the public int...      NaN
#
# [188987 rows x 12 columns]

# %%
folder_path = '/content/drive/MyDrive/Python&DataViz2025/2025-03' # Update with the actual path if different

street_files = []
for root, dirs, files in os.walk(folder_path):
  for file in files:
    if '-street' in file and file.endswith(".csv"): # Filter for '-street' in filename and assume CSVs
      file_path = os.path.join(root, file)
      df = pd.read_csv(file_path)
      street_files.append(df)

# Concatenate all DataFrames into a single DataFrame if needed
combined_street_df3 = pd.concat(street_files, ignore_index=True)

# Display the first few rows of the combined DataFrame
if street_files: # Check if the list of files is not empty
    combined_street_df = pd.concat(street_files, ignore_index=True)
    display(combined_street_df.head())
else:
    print("No files containing '-street' were found in the specified folder.")

print(f"Read {len(street_files)} files containing '-street' from {folder_path}")
# Out:
#                                             Crime ID    Month  \
# 0  94fdeeef654e81099e30fbd9e41c383b7bf8422393b13d...  2025-03
# 1  a843be1efdc13ee11aa6b852b874e24461c2e9f4813d38...  2025-03
# 2  80e578e18ad4065f45763582d20ef2ce1c14080526acf1...  2025-03
# 3  6c3257ee8b4461b574058228bd56186118c1d516c41a93...  2025-03
# 4  92f3c6cb24e35f26dcc1db4fb252f50fddefce35187afb...  2025-03
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  City of London Police  City of London Police  -0.166129  51.553632
# 1  City of London Police  City of London Police  -0.166129  51.553632
# 2  City of London Police  City of London Police  -0.109842  51.522012
# 3  City of London Police  City of London Police  -0.107682  51.517786
# 4  City of London Police  City of London Police  -0.113212  51.516841
#
#                    Location  LSOA code    LSOA name  \
# 0       On or near Hospital  E01000898  Camden 008E
# 1       On or near Hospital  E01000898  Camden 008E
# 2  On or near White Bear Yd  E01000916  Camden 027B
# 3           On or near B521  E01000917  Camden 027C
# 4     On or near Old Square  E01000914  Camden 028B
#
#                   Crime type                          Last outcome category  \
# 0      Theft from the person                            Under investigation
# 1      Theft from the person                            Under investigation
# 2                      Drugs                            Under investigation
# 3      Theft from the person  Investigation complete; no suspect identified
# 4  Criminal damage and arson                            Under investigation
#
#    Context
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# Read 5 files containing '-street' from /content/drive/MyDrive/Python&DataViz2025/2025-03

# %%
combined_street_df3
# Out:
#                                                 Crime ID    Month  \
# 0      94fdeeef654e81099e30fbd9e41c383b7bf8422393b13d...  2025-03
# 1      a843be1efdc13ee11aa6b852b874e24461c2e9f4813d38...  2025-03
# 2      80e578e18ad4065f45763582d20ef2ce1c14080526acf1...  2025-03
# 3      6c3257ee8b4461b574058228bd56186118c1d516c41a93...  2025-03
# 4      92f3c6cb24e35f26dcc1db4fb252f50fddefce35187afb...  2025-03
# ...                                                  ...      ...
# 16996  6ed624f0831ccdae6be70067ed39942b00b37178bcc159...  2025-03
# 16997  a8e120c0955fb85f040ddd2dea84351f0e254e682b716b...  2025-03
# 16998  80adea1704cf0a2c285883f3b6a2ca8060a6f0e8607127...  2025-03
# 16999  15d31236be4d13a10f8525f25195777802c0240efc06f8...  2025-03
# 17000  ea5c3d7bf27704f829cee084340ab0e2c3438df93faa22...  2025-03
#
#                  Reported by           Falls within  Longitude   Latitude  \
# 0      City of London Police  City of London Police  -0.166129  51.553632
# 1      City of London Police  City of London Police  -0.166129  51.553632
# 2      City of London Police  City of London Police  -0.109842  51.522012
# 3      City of London Police  City of London Police  -0.107682  51.517786
# 4      City of London Police  City of London Police  -0.113212  51.516841
# ...                      ...                    ...        ...        ...
# 16996       Wiltshire Police       Wiltshire Police  -1.661154  51.234168
# 16997       Wiltshire Police       Wiltshire Police  -1.661154  51.234168
# 16998       Wiltshire Police       Wiltshire Police  -1.661154  51.234168
# 16999       Wiltshire Police       Wiltshire Police  -1.661462  51.225294
# 17000       Wiltshire Police       Wiltshire Police  -1.660754  51.226245
#
#                        Location  LSOA code       LSOA name  \
# 0           On or near Hospital  E01000898     Camden 008E
# 1           On or near Hospital  E01000898     Camden 008E
# 2      On or near White Bear Yd  E01000916     Camden 027B
# 3               On or near B521  E01000917     Camden 027C
# 4         On or near Old Square  E01000914     Camden 028B
# ...                         ...        ...             ...
# 16996    On or near Supermarket  E01034558  Wiltshire 066E
# 16997    On or near Supermarket  E01034558  Wiltshire 066E
# 16998    On or near Supermarket  E01034558  Wiltshire 066E
# 16999  On or near Alamein Close  E01034558  Wiltshire 066E
# 17000      On or near Pekin Way  E01034558  Wiltshire 066E
#
#                          Crime type  \
# 0             Theft from the person
# 1             Theft from the person
# 2                             Drugs
# 3             Theft from the person
# 4         Criminal damage and arson
# ...                             ...
# 16996                   Shoplifting
# 16997  Violence and sexual offences
# 16998  Violence and sexual offences
# 16999  Violence and sexual offences
# 17000  Violence and sexual offences
#
#                                Last outcome category  Context
# 0                                Under investigation      NaN
# 1                                Under investigation      NaN
# 2                                Under investigation      NaN
# 3      Investigation complete; no suspect identified      NaN
# 4                                Under investigation      NaN
# ...                                              ...      ...
# 16996                            Under investigation      NaN
# 16997  Investigation complete; no suspect identified      NaN
# 16998                            Under investigation      NaN
# 16999                            Under investigation      NaN
# 17000                    Unable to prosecute suspect      NaN
#
# [17001 rows x 12 columns]

# %%
folder_path = '/content/drive/MyDrive/Python&DataViz2025/2025-04' # Update with the actual path if different

street_files = []
for root, dirs, files in os.walk(folder_path):
  for file in files:
    if '-street' in file and file.endswith(".csv"): # Filter for '-street' in filename and assume CSVs
      file_path = os.path.join(root, file)
      df = pd.read_csv(file_path)
      street_files.append(df)

# Concatenate all DataFrames into a single DataFrame if needed
combined_street_df4 = pd.concat(street_files, ignore_index=True)

# Display the first few rows of the combined DataFrame
if street_files: # Check if the list of files is not empty
    combined_street_df = pd.concat(street_files, ignore_index=True)
    display(combined_street_df.head())
else:
    print("No files containing '-street' were found in the specified folder.")

print(f"Read {len(street_files)} files containing '-street' from {folder_path}")
# Out:
#                                             Crime ID    Month  \
# 0  b7dc0ac996bc0c0570819482bc06dc7a17d4150ab1de42...  2025-04
# 1  c9877d69c1f144e288540abee5f9387fe293a709988b4c...  2025-04
# 2  d8402bf5cb5b34799377efaf705f84eed16b66bb34b599...  2025-04
# 3  d77a5d5b2510b92e9ecc9a8b84f99ed1918a51581e5c4b...  2025-04
# 4  b23c1207c98960afd9e0d7f2d6d1e71aa907a4245a436d...  2025-04
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  City of London Police  City of London Police  -0.107682  51.517786
# 1  City of London Police  City of London Police  -0.107682  51.517786
# 2  City of London Police  City of London Police  -0.107682  51.517786
# 3  City of London Police  City of London Police  -0.107682  51.517786
# 4  City of London Police  City of London Police  -0.111596  51.518281
#
#                    Location  LSOA code    LSOA name             Crime type  \
# 0           On or near B521  E01000917  Camden 027C            Other theft
# 1           On or near B521  E01000917  Camden 027C                Robbery
# 2           On or near B521  E01000917  Camden 027C  Theft from the person
# 3           On or near B521  E01000917  Camden 027C  Theft from the person
# 4  On or near Chancery Lane  E01000914  Camden 028B            Other theft
#
#                            Last outcome category  Context
# 0                            Under investigation      NaN
# 1                            Under investigation      NaN
# 2  Investigation complete; no suspect identified      NaN
# 3                            Under investigation      NaN
# 4  Investigation complete; no suspect identified      NaN
# Read 5 files containing '-street' from /content/drive/MyDrive/Python&DataViz2025/2025-04

# %%
combined_street_df4
# Out:
#                                                 Crime ID    Month  \
# 0      b7dc0ac996bc0c0570819482bc06dc7a17d4150ab1de42...  2025-04
# 1      c9877d69c1f144e288540abee5f9387fe293a709988b4c...  2025-04
# 2      d8402bf5cb5b34799377efaf705f84eed16b66bb34b599...  2025-04
# 3      d77a5d5b2510b92e9ecc9a8b84f99ed1918a51581e5c4b...  2025-04
# 4      b23c1207c98960afd9e0d7f2d6d1e71aa907a4245a436d...  2025-04
# ...                                                  ...      ...
# 17038  7c6166517bfae76c6c711c8b06fbd27509ec6a22d2ae84...  2025-04
# 17039  ed101c0e0f020a24133971dcac24f8b84628416c8d7ee8...  2025-04
# 17040  083694e17f6c7cca302bc7714cd52644e12d257e6b9e21...  2025-04
# 17041  ecbe79ca5c25cc42d76ab4762b08b799501ff6d2d2e82f...  2025-04
# 17042  4212ff3ceadfe1c48f8a75ffaa445a5d435a662d8eba81...  2025-04
#
#                  Reported by           Falls within  Longitude   Latitude  \
# 0      City of London Police  City of London Police  -0.107682  51.517786
# 1      City of London Police  City of London Police  -0.107682  51.517786
# 2      City of London Police  City of London Police  -0.107682  51.517786
# 3      City of London Police  City of London Police  -0.107682  51.517786
# 4      City of London Police  City of London Police  -0.111596  51.518281
# ...                      ...                    ...        ...        ...
# 17038       Wiltshire Police       Wiltshire Police  -1.662425  51.226816
# 17039       Wiltshire Police       Wiltshire Police  -1.659434  51.228471
# 17040       Wiltshire Police       Wiltshire Police  -1.659434  51.228471
# 17041       Wiltshire Police       Wiltshire Police  -1.659434  51.228471
# 17042       Wiltshire Police       Wiltshire Police  -1.659434  51.228471
#
#                             Location  LSOA code       LSOA name  \
# 0                    On or near B521  E01000917     Camden 027C
# 1                    On or near B521  E01000917     Camden 027C
# 2                    On or near B521  E01000917     Camden 027C
# 3                    On or near B521  E01000917     Camden 027C
# 4           On or near Chancery Lane  E01000914     Camden 028B
# ...                              ...        ...             ...
# 17038  On or near Rorkes Drift Drive  E01034558  Wiltshire 066E
# 17039          On or near Minden Way  E01034558  Wiltshire 066E
# 17040          On or near Minden Way  E01034558  Wiltshire 066E
# 17041          On or near Minden Way  E01034558  Wiltshire 066E
# 17042          On or near Minden Way  E01034558  Wiltshire 066E
#
#                          Crime type  \
# 0                       Other theft
# 1                           Robbery
# 2             Theft from the person
# 3             Theft from the person
# 4                       Other theft
# ...                             ...
# 17038  Violence and sexual offences
# 17039  Violence and sexual offences
# 17040  Violence and sexual offences
# 17041  Violence and sexual offences
# 17042  Violence and sexual offences
#
#                                Last outcome category  Context
# 0                                Under investigation      NaN
# 1                                Under investigation      NaN
# 2      Investigation complete; no suspect identified      NaN
# 3                                Under investigation      NaN
# 4      Investigation complete; no suspect identified      NaN
# ...                                              ...      ...
# 17038  Investigation complete; no suspect identified      NaN
# 17039     Action to be taken by another organisation      NaN
# 17040     Action to be taken by another organisation      NaN
# 17041     Action to be taken by another organisation      NaN
# 17042     Action to be taken by another organisation      NaN
#
# [17043 rows x 12 columns]

# %%
folder_path = '/content/drive/MyDrive/Python&DataViz2025/2025-05' # Update with the actual path if different

street_files = []
for root, dirs, files in os.walk(folder_path):
  for file in files:
    if '-street' in file and file.endswith(".csv"): # Filter for '-street' in filename and assume CSVs
      file_path = os.path.join(root, file)
      df = pd.read_csv(file_path)
      street_files.append(df)

# Concatenate all DataFrames into a single DataFrame if needed
combined_street_df5 = pd.concat(street_files, ignore_index=True)

# Display the first few rows of the combined DataFrame
if street_files: # Check if the list of files is not empty
    combined_street_df = pd.concat(street_files, ignore_index=True)
    display(combined_street_df.head())
else:
    print("No files containing '-street' were found in the specified folder.")

print(f"Read {len(street_files)} files containing '-street' from {folder_path}")
# Out:
#                                             Crime ID    Month  \
# 0  5dcf36aec35688cb126aabd863e5eb6bddbfef1dee38bc...  2025-05
# 1  f9e4f9726398ef0f502a8911c1bdb430ba1c43e412ffaa...  2025-05
# 2  16a2675a311106362fd1043c3ee3e63b036a8fe426a96e...  2025-05
# 3  ba09efb4456db3968fa23673d8d4995da8927070f58427...  2025-05
# 4  9abc33a127821dcba1596179c5fa47534489aed65bfdfc...  2025-05
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  City of London Police  City of London Police   0.146760  51.575276
# 1  City of London Police  City of London Police   0.147922  51.544220
# 2  City of London Police  City of London Police   0.083079  51.536640
# 3  City of London Police  City of London Police  -2.456113  53.584816
# 4  City of London Police  City of London Police  -0.163522  51.536344
#
#                           Location  LSOA code                  LSOA name  \
# 0         On or near Sylvan Avenue  E01000110  Barking and Dagenham 002C
# 1                 On or near A1240  E01000013  Barking and Dagenham 013A
# 2    On or near Sunningdale Avenue  E01034473  Barking and Dagenham 015E
# 3  On or near Back Mornington Road  E01004922                Bolton 015E
# 4           On or near Cecil Grove  E01000967                Camden 017D
#
#                      Crime type Last outcome category  Context
# 0                 Vehicle crime   Under investigation      NaN
# 1  Violence and sexual offences   Under investigation      NaN
# 2                   Other crime   Under investigation      NaN
# 3                   Other crime   Under investigation      NaN
# 4  Violence and sexual offences   Under investigation      NaN
# Read 5 files containing '-street' from /content/drive/MyDrive/Python&DataViz2025/2025-05

# %%
combined_street_df5
# Out:
#                                                 Crime ID    Month  \
# 0      5dcf36aec35688cb126aabd863e5eb6bddbfef1dee38bc...  2025-05
# 1      f9e4f9726398ef0f502a8911c1bdb430ba1c43e412ffaa...  2025-05
# 2      16a2675a311106362fd1043c3ee3e63b036a8fe426a96e...  2025-05
# 3      ba09efb4456db3968fa23673d8d4995da8927070f58427...  2025-05
# 4      9abc33a127821dcba1596179c5fa47534489aed65bfdfc...  2025-05
# ...                                                  ...      ...
# 17940  c73a19e8066d8b25412ad81d00f9b54fae91ef30093f91...  2025-05
# 17941  e6912d9619a46e5bd3c497df787c1fd33e8ef2e62d4a49...  2025-05
# 17942  21f16dedc869d33913f9d004a3e95913e5d8fa2e6b5a5f...  2025-05
# 17943  0ac70d59536954f60110fb47d338d40d486314af217a8b...  2025-05
# 17944  84ea5f38b46e9f567d9b4e2259e366f370cb8a913852be...  2025-05
#
#                  Reported by           Falls within  Longitude   Latitude  \
# 0      City of London Police  City of London Police   0.146760  51.575276
# 1      City of London Police  City of London Police   0.147922  51.544220
# 2      City of London Police  City of London Police   0.083079  51.536640
# 3      City of London Police  City of London Police  -2.456113  53.584816
# 4      City of London Police  City of London Police  -0.163522  51.536344
# ...                      ...                    ...        ...        ...
# 17940       Wiltshire Police       Wiltshire Police  -1.661154  51.234168
# 17941       Wiltshire Police       Wiltshire Police  -1.660471  51.225777
# 17942       Wiltshire Police       Wiltshire Police  -1.661154  51.234168
# 17943       Wiltshire Police       Wiltshire Police  -1.660471  51.225777
# 17944       Wiltshire Police       Wiltshire Police  -1.660922  51.234554
#
#                               Location  LSOA code                  LSOA name  \
# 0             On or near Sylvan Avenue  E01000110  Barking and Dagenham 002C
# 1                     On or near A1240  E01000013  Barking and Dagenham 013A
# 2        On or near Sunningdale Avenue  E01034473  Barking and Dagenham 015E
# 3      On or near Back Mornington Road  E01004922                Bolton 015E
# 4               On or near Cecil Grove  E01000967                Camden 017D
# ...                                ...        ...                        ...
# 17940           On or near Supermarket  E01034558             Wiltshire 066E
# 17941        On or near Ramnuggur Road  E01034558             Wiltshire 066E
# 17942           On or near Supermarket  E01034558             Wiltshire 066E
# 17943        On or near Ramnuggur Road  E01034558             Wiltshire 066E
# 17944          On or near Station Road  E01034558             Wiltshire 066E
#
#                          Crime type        Last outcome category  Context
# 0                     Vehicle crime          Under investigation      NaN
# 1      Violence and sexual offences          Under investigation      NaN
# 2                       Other crime          Under investigation      NaN
# 3                       Other crime          Under investigation      NaN
# 4      Violence and sexual offences          Under investigation      NaN
# ...                             ...                          ...      ...
# 17940                   Shoplifting          Under investigation      NaN
# 17941  Violence and sexual offences          Under investigation      NaN
# 17942  Violence and sexual offences          Under investigation      NaN
# 17943  Violence and sexual offences          Under investigation      NaN
# 17944  Violence and sexual offences  Unable to prosecute suspect      NaN
#
# [17945 rows x 12 columns]

# %%
all_street_df = pd.concat([combined_street_df1, combined_street_df2, combined_street_df3, combined_street_df4, combined_street_df5], ignore_index=True)

# %%
all_street_df
# Out:
#                                                  Crime ID    Month  \
# 0       8c7661d1b68d476454c5b68a58daee0d91781a94f60015...  2025-01
# 1       1b7fbc8deac5182e6b1e580ab4eb4ed520df688c3576bc...  2025-01
# 2       8476f32b188fae2d0d14b7db79e872fd7688f064e8ced3...  2025-01
# 3       92b8de6e45c3b711e802fb9d99e2a030c3f56b1c589e55...  2025-01
# 4       023587ed2c674a28bd52d6e03d505c3b0dba6d25e8b95b...  2025-01
# ...                                                   ...      ...
# 684671  c73a19e8066d8b25412ad81d00f9b54fae91ef30093f91...  2025-05
# 684672  e6912d9619a46e5bd3c497df787c1fd33e8ef2e62d4a49...  2025-05
# 684673  21f16dedc869d33913f9d004a3e95913e5d8fa2e6b5a5f...  2025-05
# 684674  0ac70d59536954f60110fb47d338d40d486314af217a8b...  2025-05
# 684675  84ea5f38b46e9f567d9b4e2259e366f370cb8a913852be...  2025-05
#
#                   Reported by           Falls within  Longitude   Latitude  \
# 0       City of London Police  City of London Police  -0.107682  51.517786
# 1       City of London Police  City of London Police  -0.111596  51.518281
# 2       City of London Police  City of London Police  -0.097078  51.519045
# 3       City of London Police  City of London Police  -0.097290  51.521575
# 4       City of London Police  City of London Police  -0.098519  51.517332
# ...                       ...                    ...        ...        ...
# 684671       Wiltshire Police       Wiltshire Police  -1.661154  51.234168
# 684672       Wiltshire Police       Wiltshire Police  -1.660471  51.225777
# 684673       Wiltshire Police       Wiltshire Police  -1.661154  51.234168
# 684674       Wiltshire Police       Wiltshire Police  -1.660471  51.225777
# 684675       Wiltshire Police       Wiltshire Police  -1.660922  51.234554
#
#                          Location  LSOA code            LSOA name  \
# 0                 On or near B521  E01000917          Camden 027C
# 1        On or near Chancery Lane  E01000914          Camden 028B
# 2                   On or near A1  E01000001  City of London 001A
# 3          On or near Fann Street  E01000001  City of London 001A
# 4       On or near Little Britain  E01000001  City of London 001A
# ...                           ...        ...                  ...
# 684671     On or near Supermarket  E01034558       Wiltshire 066E
# 684672  On or near Ramnuggur Road  E01034558       Wiltshire 066E
# 684673     On or near Supermarket  E01034558       Wiltshire 066E
# 684674  On or near Ramnuggur Road  E01034558       Wiltshire 066E
# 684675    On or near Station Road  E01034558       Wiltshire 066E
#
#                           Crime type  \
# 0                        Other theft
# 1              Theft from the person
# 2                              Drugs
# 3                        Other theft
# 4                        Other theft
# ...                              ...
# 684671                   Shoplifting
# 684672  Violence and sexual offences
# 684673  Violence and sexual offences
# 684674  Violence and sexual offences
# 684675  Violence and sexual offences
#
#                                     Last outcome category  Context
# 0           Investigation complete; no suspect identified      NaN
# 1           Investigation complete; no suspect identified      NaN
# 2       Further investigation is not in the public int...      NaN
# 3           Investigation complete; no suspect identified      NaN
# 4           Investigation complete; no suspect identified      NaN
# ...                                                   ...      ...
# 684671                                Under investigation      NaN
# 684672                                Under investigation      NaN
# 684673                                Under investigation      NaN
# 684674                                Under investigation      NaN
# 684675                        Unable to prosecute suspect      NaN
#
# [684676 rows x 12 columns]

# %%
# each months select only street files with every city
